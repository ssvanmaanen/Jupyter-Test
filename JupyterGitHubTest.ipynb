# %% [markdown]
# # Topic 8 - Data Frames
# Practise setting up a data frame (slide 14)

# %%
import pandas as pd
df = pd.DataFrame({'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]})
print(df)
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %% [markdown]
# Reading a .csv file (slide 15)

# %%
test_df = pd.read_csv("test.csv")
print(test_df)
# Out:
#    region_id  Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  Age_0_4_yr_F  \
# 0     CED501    77665    78074   155739          6424          6152
# 1     CED502    73557    73947   147504          5371          4891
# 2     CED503    70404    72011   142415          5377          5197
# 3     CED504    67911    70635   138546          3862          3743
# 4     CED505    98212    79032   177244          6928          6477
# 5     CED506    69634    69797   139431          5080          4743
# 6     CED507    71076    73335   144411          5153          4769
# 7     CED508    74414    74914   149328          5358          5017
# 8     CED509    71597    72851   144448          4850          4636
# 9     CED510    77268    73121   150389          5539          5305
# 10    CED511    76942    76977   153919          5880          5451
# 11    CED512    73259    71805   145064          4367          3965
# 12    CED513    69743    72238   141981          4755          4605
# ...

# %%
type(test_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
test_df.dtypes
# Out:
# region_id                        object
# Tot_P_M                           int64
# Tot_P_F                           int64
# Tot_P_P                           int64
# Age_0_4_yr_M                      int64
# Age_0_4_yr_F                      int64
# Age_0_4_yr_P                      int64
# Age_5_14_yr_M                     int64
# Age_5_14_yr_F                     int64
# Age_5_14_yr_P                     int64
# Age_15_19_yr_M                    int64
# Age_15_19_yr_F                    int64
# Age_15_19_yr_P                    int64
# Age_20_24_yr_M                    int64
# Age_20_24_yr_F                    int64
# Age_20_24_yr_P                    int64
# Age_25_34_yr_M                    int64
# Age_25_34_yr_F                    int64
# Age_25_34_yr_P                    int64
# Age_35_44_yr_M                    int64
# Age_35_44_yr_F                    int64
# Age_35_44_yr_P                    int64
# Age_45_54_yr_M                    int64
# ...

# %%
test_df.columns
# Out:
# Index(['region_id', 'Tot_P_M', 'Tot_P_F', 'Tot_P_P', 'Age_0_4_yr_M',
#        'Age_0_4_yr_F', 'Age_0_4_yr_P', 'Age_5_14_yr_M', 'Age_5_14_yr_F',
#        'Age_5_14_yr_P',
#        ...
#        'High_yr_schl_comp_Yr_8_belw_P', 'High_yr_schl_comp_D_n_g_sch_M',
#        'High_yr_schl_comp_D_n_g_sch_F', 'High_yr_schl_comp_D_n_g_sch_P',
#        'Count_psns_occ_priv_dwgs_M', 'Count_psns_occ_priv_dwgs_F',
#        'Count_psns_occ_priv_dwgs_P', 'Count_Persons_other_dwgs_M',
#        'Count_Persons_other_dwgs_F', 'Count_Persons_other_dwgs_P'],
#       dtype='object', length=109)

# %%
test_df.shape
# Out:
# (17, 109)

# %%
test_df.head
# Out:
# <bound method NDFrame.head of    region_id  Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  Age_0_4_yr_F  \
# 0     CED501    77665    78074   155739          6424          6152
# 1     CED502    73557    73947   147504          5371          4891
# 2     CED503    70404    72011   142415          5377          5197
# 3     CED504    67911    70635   138546          3862          3743
# 4     CED505    98212    79032   177244          6928          6477
# 5     CED506    69634    69797   139431          5080          4743
# 6     CED507    71076    73335   144411          5153          4769
# 7     CED508    74414    74914   149328          5358          5017
# 8     CED509    71597    72851   144448          4850          4636
# 9     CED510    77268    73121   150389          5539          5305
# 10    CED511    76942    76977   153919          5880          5451
# 11    CED512    73259    71805   145064          4367          3965
# ...

# %%
test_df.columns.values
# Out:
# array(['region_id', 'Tot_P_M', 'Tot_P_F', 'Tot_P_P', 'Age_0_4_yr_M',
#        'Age_0_4_yr_F', 'Age_0_4_yr_P', 'Age_5_14_yr_M', 'Age_5_14_yr_F',
#        'Age_5_14_yr_P', 'Age_15_19_yr_M', 'Age_15_19_yr_F',
#        'Age_15_19_yr_P', 'Age_20_24_yr_M', 'Age_20_24_yr_F',
#        'Age_20_24_yr_P', 'Age_25_34_yr_M', 'Age_25_34_yr_F',
#        'Age_25_34_yr_P', 'Age_35_44_yr_M', 'Age_35_44_yr_F',
#        'Age_35_44_yr_P', 'Age_45_54_yr_M', 'Age_45_54_yr_F',
#        'Age_45_54_yr_P', 'Age_55_64_yr_M', 'Age_55_64_yr_F',
#        'Age_55_64_yr_P', 'Age_65_74_yr_M', 'Age_65_74_yr_F',
#        'Age_65_74_yr_P', 'Age_75_84_yr_M', 'Age_75_84_yr_F',
#        'Age_75_84_yr_P', 'Age_85ov_M', 'Age_85ov_F', 'Age_85ov_P',
#        'Counted_Census_Night_home_M', 'Counted_Census_Night_home_F',
#        'Counted_Census_Night_home_P', 'Count_Census_Nt_Ewhere_Aust_M',
#        'Count_Census_Nt_Ewhere_Aust_F', 'Count_Census_Nt_Ewhere_Aust_P',
# ...

# %%
pd.unique(test_df['Lang_spoken_home_Eng_only_P'])
# Out:
# array([136136, 129317, 109014, 109676, 138422, 124273, 113513, 120735,
#        123438, 130466, 131819, 100222,  96033, 104556, 102682,   5336,
#           309])

# %%
test_df['Lang_spoken_home_Eng_only_P'].describe()
# Out:
# count        17.000000
# mean     104467.470588
# std       40398.115632
# min         309.000000
# 25%      102682.000000
# 50%      113513.000000
# 75%      129317.000000
# max      138422.000000
# Name: Lang_spoken_home_Eng_only_P, dtype: float64

# %%
sorted_data = test_df.groupby('High_yr_schl_comp_Yr_8_belw_P')

# %%
print(sorted_data)

# %%
sorted_data.describe()
# Out:
#                               Age_0_4_yr_F                              \
#                                      count    mean std     min     25%
# High_yr_schl_comp_Yr_8_belw_P
# 6                                      1.0     0.0 NaN     0.0     0.0
# 228                                    1.0   134.0 NaN   134.0   134.0
# 2046                                   1.0  4636.0 NaN  4636.0  4636.0
# 2153                                   1.0  3743.0 NaN  3743.0  3743.0
# 3012                                   1.0  3557.0 NaN  3557.0  3557.0
# 4017                                   1.0  5451.0 NaN  5451.0  5451.0
# 4277                                   1.0  5197.0 NaN  5197.0  5197.0
# 4415                                   1.0  6152.0 NaN  6152.0  6152.0
# 4756                                   1.0  4743.0 NaN  4743.0  4743.0
# 4988                                   1.0  5017.0 NaN  5017.0  5017.0
# 5107                                   1.0  4891.0 NaN  4891.0  4891.0
# ...

# %%
sorted_data.mean()
# Out:
#                                Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  \
# High_yr_schl_comp_Yr_8_belw_P
# 6                                  382       34      416             0
# 228                               4287     3011     7298           126
# 2046                             71597    72851   144448          4850
# 2153                             67911    70635   138546          3862
# 3012                             69699    72239   141938          3880
# 4017                             76942    76977   153919          5880
# 4277                             70404    72011   142415          5377
# 4415                             77665    78074   155739          6424
# 4756                             69634    69797   139431          5080
# 4988                             74414    74914   149328          5358
# 5107                             73557    73947   147504          5371
# 5370                             80126    78974   159100          4905
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

sorted_data.plot(kind='bar')
plt.show()
